# %%
## Use beautiful soup to scrape data from cargurus

# %%
from bs4 import BeautifulSoup
import requests
#from selenium import webdriver
import pandas
import time
import os

# %%
zipcode = 13775
pages = 100
data_name = "new3"

# %%
link = "https://www.cargurus.com/Cars/inventorylisting/viewDetailsFilterViewInventoryListing.action?sourceContext=carGurusHomePage_false_0&formSourceTag=112&newSearchFromOverviewPage=true&inventorySearchWidgetType=AUTO&entitySelectingHelper.selectedEntity=&entitySelectingHelper.selectedEntity2=&zip={}&distance=100&searchChanged=true&modelChanged=true&filtersModified=true".format(zipcode)
raw_data = "_data/_{}_raw.csv".format(data_name)
clean_data = "_data/_{}_clean.csv".format(data_name)

print("\n ** ready to extract data from: {}...{}".format(link[:20], link[-20:]))
print("\n ** pages processing: {}".format(pages))



data = []
# Out:
#  ** ready to extract data from: https://www.cargurus...filtersModified=true
#
#  ** pages processing: 100

# %%
r = requests.get(link)
content = r.content
soup = BeautifulSoup(content)
# Out:
# /home/earneodo/anaconda3/envs/tf12/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/earneodo/anaconda3/envs/tf12/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
soup.find_all()
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="ie6 app_en appc_US appl_en BLACKOUT_TEXAS" lang="en"> <![endif]--><!--[if IE 7]>         <html class="ie7 app_en appc_US appl_en BLACKOUT_TEXAS" lang="en"> <![endif]--><!--[if IE 8]>         <html class="ie8 app_en appc_US appl_en BLACKOUT_TEXAS" lang="en"> <![endif]--><!--[if IE 9]>         <html class="ie9 app_en appc_US appl_en BLACKOUT_TEXAS" lang="en"> <![endif]--><!--[if !IE]> --><html class="app_en appc_US appl_en BLACKOUT_TEXAS" lang="en"><!-- <![endif]--><head>
#     <script>
#         googleTagDataLayer = [];
#     </script>
#
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','googleTagDataLayer','GTM-PMJ79F');</script>
#
#   <script type="text/javascript">
#         window.startTime = (new Date).getTime();
#   </script>
#
#
#
#     <script type="application/ld+json">
#     {
#       "@context": "http://schema.org",
#       "@type": "Organization",
#       "url": "https://www.cargurus.com/",
#       "logo": "https://static1.cargurus.com/gfx/cg/logos/cgLogo_280x50.png",
#       "sameAs": [
#         "https://www.facebook.com/cargurus",
#         "https://www.twitter.com/cargurus",
#         "https://www.pinterest.com/cargurus",
#         "https://www.youtube.com/cargurus",
#         "https://instagram.com/cargurus",
#         "https://www.linkedin.com/in/cargurus",
#         "https://plus.google.com/+cargurus"
#       ]
#     }
#     </script>
#
#     <title>Used Cars For Sale. Find used and pre-owned cars in Franklin, NY - CarGurus</title>
#     <meta content=" Search pre-owned used car listings to find the best Franklin, NY deals. CarGurus analyzes over 6 million cars daily." name="description"/>
#     <meta content="width=device-width, height=device-height, initial-scale=1, maximum-scale=1, user-scalable=no, shrink-to-fit=no, viewport-fit=cover" name="viewport"/>
#         <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#         <meta content="no-cache" http-equiv="pragma"/>
#         <meta content="no-cache,no-store,must-revalidate" http-equiv="cache-control"/>
#         <meta content="0" http-equiv="expires"/>
#         <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#         <meta content="en" http-equiv="content-language"/>
#         <meta content="true" name="msapplication-allowDomainMetaTags"/>
#         <meta content="https://static1.cargurus.com/gfx/logos/windowsTiles/CG-ms-logo-med.png" name="msapplication-square150x150logo"/>
#         <meta content="https://static1.cargurus.com/gfx/logos/windowsTiles/CG-ms-logo-small.png" name="msapplication-square70x70logo"/>
#         <meta content="https://static1.cargurus.com/gfx/logos/windowsTiles/CG-ms-logo-wide.png" name="msapplication-wide310x150logo"/>
#         <meta content="#0099FF" name="msapplication-TileColor"/>
#         <meta content="browserconfig.xml" name="msapplication-config"/>
#
# <meta data-application-locale-id="en" data-blackout-texas="true" data-country-code="US" data-device-os="DESKTOP" data-email-hash="" data-language-tag="en" data-locale-id="en_US" data-locale-namespace="/Cars" data-logged-in="false" data-mobile-app="false" data-production="true" data-supported-client="false" data-uuid="bvr1-132.239.147.118.1525126959733" data-view-version="_DEFAULT_" name="envInfo"/>
#
# <meta data-action-class="com.cargurus.site.action.inventorylisting.InventoryListingAction" data-action-method="viewDetailsFilterView" data-build-id="cg-main-16350" data-production="true" data-sentry="https://0e1a93256b16472d9067a95b7c2017f7@sentry.io/100939" data-sentry-integrated="true" data-server-host-name="www05.cargurus.com" data-template="/inventorylisting/viewDetailsFilterView.ftl" data-view-version="_DEFAULT_" name="devInfo"/>
#
#
#   <meta content="199331106902" property="fb:app_id"/>
#
# <meta content="CarGurus" property="og:site_name"/>
#
# <meta content="product" property="og:type"/>
# <meta content="https://www.cargurus.com/Cars/forsale" property="og:url"/>
# <meta content="CarGurus - Find great car deals" property="og:title"/>
#   <meta content="https://static1.cargurus.com/gfx/logos/CarGurusOpenGraphLogox200.png" property="og:image"/>
#
#
#
#         <link href="https://static3.cargurus.com/bundles/css/cg_ext_global.692c9cc081a047ce9858.css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="https://static3.cargurus.com/bundles/css/cg_site_globalV2.9121c22751ef4db891be.css" media="all" rel="stylesheet" type="text/css"/>
#
# <link href="https://static3.cargurus.com/css/site/core/cg-highres.css?v=-430879965_157" media="only screen and (min--moz-device-pixel-ratio: 2), only screen and (-o-min-device-pixel-ratio: 2/1), only screen and (-webkit-min-device-pixel-ratio: 2), only screen and (min-device-pixel-ratio: 2)" rel="stylesheet"/>
#
#         <link href="https://static3.cargurus.com/bundles/css/cg_site_dealfinder.1a841137d8cf429d912c.css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="https://static3.cargurus.com/bundles/css/contact_a_dealer.f1269e5b78d54828923d.css" media="all" rel="stylesheet" type="text/css"/>
#
# <!--[if lt IE 9]>
# <link rel="stylesheet" type="text/css" media="all" href="https://static3.cargurus.com/css/external/jquery/movingBoxes/movingboxes-ie.css?v=289181485_765">
# <![endif]-->
# <link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <script src="https://static4.cargurus.com/bundles/js/ext_lib.ec624529795490bc138774c8bf922890.js" type="text/javascript"></script>
# <script src="https://static4.cargurus.com/bundles/js/highcharts.2ce2d2c128d29b315a5f6cf13bb5f270.js" type="text/javascript"></script>
# <script src="https://static4.cargurus.com/bundles/js/jquery_ui.36df92b49b31956b310dbbab43a9d2b0.js" type="text/javascript"></script>
# <script src="https://static4.cargurus.com/bundles/js/highcharts_dep.8c4245acb2d70e28b309a8cc62334138.js" type="text/javascript"></script>
#
# <script src="https://static4.cargurus.com/bundles/js/inventorylistings.en_US.b90cf28f45507429f21c8ace9d1ccae5.js" type="text/javascript"></script>
# <script src="https://static4.cargurus.com/bundles/js/inventorylistings.eaaeaf9c389e1263dd80c0e15d0a82a2.js" type="text/javascript"></script>
#
#
#
#
# <script type="text/javascript">
#     $(document).ready(function() {
#         // Sets the cookie if the href of the current window is a paid search URL.
#         CG.CookieUtils.setPaidReferrerCookie();
#
#         //This is required so that deep objects (like arrays don't get serialized
#         //in a "new" way).  This change is as of jquery 1.4.3
#         $.ajaxSettings.traditional = true;
#         $(document).ajaxError(CG.Utils.defaultAjaxErrorHandler);
#
#
#
#
#     });
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <link href="https://www.cargurus.com/es/spt_carros_usados-Franklin_L24165" hreflang="es-US" rel="alternate"/>
#
#   <link href="https://www.cargurus.com/Cars/spt_used_cars-Franklin_L24165" rel="canonical"/>
#
#
#   <link href="https://www.cargurus.com/Cars/spt_used_cars-Franklin_L24165?page=2" rel="next"/>
#     <meta content="origin-when-crossorigin" name="referrer"/>
#
#
#   <style type="text/css">
#       .mainNav-inner .glyphicon-menu-hamburger{display: none;}
#   </style>
#
#
#
#   <!--[if lt IE 9]>
#   <script language="javascript" charset="utf-8" type="text/javascript" src="  https://static4.cargurus.com/js/html5shiv/html5shiv.js?v=-2131433405_10105
# "></script>
#   <![endif]-->
#
#
#
# <script>
#     var gaAccountNumber = 'UA-4745999-1';
#   window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#   ga('create', gaAccountNumber, 'auto');
# </script>
# <script async="" src="https://www.google-analytics.com/analytics.js"></script>
#
# <script type="text/javascript">
#   if (typeof cgDataLayer === 'object' && cgDataLayer !== null && cgDataLayer.baseData) {
#       cgDataLayer.baseData['ViewVersion'] = "_DEFAULT_";
#       cgDataLayer.baseData['ViewabilityViewVersion'] = "A";
#       cgDataLayer.baseData['CGLocale']="ENGLISH";
#       cgDataLayer.baseData['Locale']='en_US';
#       cgDataLayer.baseData['Country']='UNITED_STATES';
#     cgDataLayer.baseData['UUID']="bvr1-132.239.147.118.1525126959733";
#       cgDataLayer.baseData['PostalCode'] = "13775";
#       cgDataLayer.baseData['City'] = "Franklin";
#       cgDataLayer.baseData['Region'] = "NY";
#       cgDataLayer.baseData['SiteSection'] = "Used Cars";
#     cgDataLayer.baseData['SiteSectionName'] = 'For Sale';
#     cgDataLayer.baseData['Login'] = false;
#             cgDataLayer.baseData['AgeRange']=["none"];
#             cgDataLayer.baseData['CPO']="false";
#             cgDataLayer.baseData['Product']="listings";
#             cgDataLayer.baseData['PageType']="usedcar";
#
#
#
#       cgDataLayer.baseData['SectionId'] = "listings";
#
#     cgDataLayer.resetPageData();
#   }
# </script>
#   <script type="text/javascript">
#     (function() {
#       var scripts = document.getElementsByTagName('script')[0];
#       var s = document.createElement('script');
#       s.async = true;
#       s.src = "//tags.bkrtx.com/js/bk-coretag.js";
#       scripts.parentNode.insertBefore(s, scripts);
#     }());
#     if (typeof cgDataLayer === 'object' && cgDataLayer !== null && cgDataLayer.baseData) {
#       cgDataLayer.baseData['BKdsid']=26877;
#       cgDataLayer.baseData['BKmsid']=26878;
#
#       cgDataLayer.resetPageData();
#     }
#   </script>
#   <!-- BEGIN Krux ControlTag for "CarGurus.com" -->
#   <script class="kxct" data-id="rxu29fkdu" data-timing="async" data-version="3.0" type="text/javascript">
#       window.Krux||((Krux=function(){Krux.q.push(arguments)}).q=[]);
#       (function(){
#           var k=document.createElement('script');k.type='text/javascript';k.async=true;
#           k.src=(location.protocol==='https:'?'https:':'http:')+'//cdn.krxd.net/controltag/rxu29fkdu.js';
#           var s=document.getElementsByTagName('script')[0];s.parentNode.insertBefore(k,s);
#       }());
#   </script>
#   <!-- END Krux ControlTag -->
#
#   <!-- BEGIN Krux O&O Tag -->
#   <script class="kxint" data-namespace="cargurus" type="text/javascript">
#       window.Krux||((Krux=function(){Krux.q.push(arguments);}).q=[]);
#       (function(){
#           function retrieve(n){
#               var k= 'kx'+'cargurus_'+n, ls=(function(){
#                   try {
#                       return window.localStorage;
#                   } catch(e) {
#                       return null;
#                   }
#               })();
#               if (ls) {
#                   return ls[k] || '';
#               } else if (navigator.cookieEnabled) {
#                   var m = document.cookie.match(k+'=([^;]*)');
#                   return (m && unescape(m[1])) || '';
#               } else {
#                   return '';
#               }
#           }
#           Krux.user = retrieve('user');
#           Krux.segments = retrieve('segs') ? retrieve('segs').split(',') : [];
#       })();
#   </script>
#   <!-- END Krux O&O Tag -->
#
#
# <script type="text/javascript">
#   (function () {
#     var openx_script_tag = document.createElement('script');
#     openx_script_tag.type = 'text/javascript';
#     openx_script_tag.src = "//cargurus-d.openx.net/w/1.0/jstag?nc=19485787-CarGurus";
#     openx_script_tag.async = true;
#     openx_script_tag.onload = function () {
#       var gpt_script_tag = document.createElement('script');
#       gpt_script_tag.type = 'text/javascript';
#       gpt_script_tag.src = "//www.googletagservices.com/tag/js/gpt.js";
#       gpt_script_tag.async = true;
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(gpt_script_tag, s);
#     };
#     var existingScriptElement = document.getElementsByTagName('script')[0];
#     existingScriptElement.parentNode.insertBefore(openx_script_tag, existingScriptElement);
#   }());
# </script>
#
# <script type="text/javascript">var googletag = window.googletag = window.googletag || { cmd: [] };</script>
#
# <script data-ad-page-targeting='{ "dma": "none", "mobileSite": "false", "sZipUS": "none", "adsense_hints": " Franklin New York", "adsense_channel_ids": "5696859814", "remnant_ad_id": "1", "firstHit": "true" }' src="https://static4.cargurus.com/bundles/js/ads.entry.6e6cc20aa790a1d8c5b6f74e289686c4.js" type="text/javascript"></script>
# </head>
#
# <body>
#     <noscript>&lt;iframe src="//www.googletagmanager.com/ns.html?id=GTM-PMJ79F"
#         height="0" width="0" style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;</noscript>
#     <script>
#         if (typeof CG === 'object' && CG !== null && CG.hasOwnProperty('GoogleData') && !!CG.GoogleData.SiteTabs) {
#           CG.GoogleData.SiteTabs.RESEARCH = 'Research';
#           CG.GoogleData.SiteTabs.QUESTIONS = 'Questions';
#           CG.GoogleData.SiteTabs.FOR_SALE = 'Used Cars';
#           CG.GoogleData.SiteTabs.DEALERS = 'Dealers';
#           CG.GoogleData.SiteTabs.REPAIRS = 'Repairs';
#           CG.GoogleData.SiteTabs.SELL_CAR = 'Sell My Car';
#           CG.GoogleData.SiteTabs.NEW_CAR = 'New Cars';
#         }
#     </script>
#
#
#
#
# <header class="cg-header-wrap" role="banner">
#   <div class="header ">
#   	<div class="header-inner clearfix">
#   	</div>
#   </div>
# </header>
# <div class="" id="wrapper">
#   <nav class="mainNav">
# 	<div class="mainNav-inner clearfix">
#       <div class="glyphicon glyphicon-menu-hamburger pull-left hidden-md hidden-lg" onclick="$('.cg-header-tabs').toggle();" style="cursor: pointer;font-size: 1em;padding: .5em .5em 0;"></div>
#     <a href="/">
#     <div class="cg-sprite-header-cgLogo_280x50 cg-siteHeader-cgLogo" style="width:280px; float:left;">
#         CarGurus
#     </div>
#     </a>
#
#   <nav class="cg-siteHeader-authBar-wrap clearfix pull-right">
#     <style>
#         #toolsMenu li {text-align: left;}
#         .dropdown:hover{cursor: pointer;}
#         .dropdown:hover > ul.dropdown-menu {display: block;}
#         .cg-siteHeader-authBar-welcomeMessage ul.dropdown-menu {min-width: 200px;}
#         html.app_de_DE .cg-siteHeader-authBar-welcomeMessage ul.dropdown-menu {min-width: 250px;}
#         html.app_es_ES .cg-siteHeader-authBar-welcomeMessage ul.dropdown-menu {min-width: 250px;}
#         html.app_fr_ca .cg-siteHeader-authBar-welcomeMessage ul.dropdown-menu {min-width: 250px;}
#     </style>
#     <div id="authBar">
#
#   <!-- notifications -->
#     <div class="cg-siteHeader-authBar-option cg-siteHeader-authBar-notification-icon btn-group">
#       <a aria-controls="dropdown-cgNotificationsMenuDesktop" aria-haspopup="true" aria-owns="dropdown-cgNotificationsMenuDesktop" class="nav dropdown" data-html="true" data-placement="bottom" data-toggle="popover" id="cgNotificationsMenuDesktop" role="button" style="display:none">
#         <div class="glyphicon glyphicon-bell">
#           <div class="badge" style="display:none">0</div>
#         </div>
#       </a>
#     </div>
#
#   <!-- Dealer Dashboard -->
#
#   <!-- advertise link -->
#     <div class="cg-siteHeader-authBar-option">
#       <span class="slnk " id="" onclick="CG.Utils.slnk('L0NhcnMvZGVhbGVyL3NpZ251cD9waWQ9QWR2ZXJ0aXNlSGVhZGVyTGluaw__', false);" title="Advertise">Advertise</span>
#     </div>
#
#   <!-- Join Link -->
#     <div class="cg-siteHeader-authBar-option">
#       <span class="slnk " id="" onclick="CG.Utils.slnk('..._', false);" title="Join">Join</span>
#     </div>
#
#   <!-- user account name and menu if logged in-->
# <div class="ft-account-menu cg-siteHeader-authBar-option cg-siteHeader-authBar-welcomeMessage dropdown">      <style>
#         #toolsMenu li {text-align: left;}
#         .dropdown:hover{cursor: pointer;}
#         .dropdown:hover > ul.dropdown-menu {display: block;}
#       </style>
#       <a aria-controls="dropdown-toolsMenu" aria-haspopup="true" aria-owns="dropdown-toolsMenu" class="nav dropdown-toggle ft-tool-menu-toggle" data-toggle="dropdown" href="javascript:;" id="toolsMenu" role="button">
#         <span class="ft-user-name">
#             My account
#         </span>
# <b class="caret" role="presentation"></b>      </a>
#       <ul aria-labelledby="toolsMenu" class="dropdown-menu pull-right" id="dropdown-toolsMenu" role="menu">
#
#                 <li role="presentation"><a class="clearfix" href="/Cars/forsale" role="menuitem"><div class="pull-left">Saved searches</div><div class="badge badge-info pull-right" id="cg-menu-savedSearch"></div></a></li>
#               <li role="presentation"><a class="clearfix" href="/Cars/inventorylisting/mySavedListings.action" role="menuitem"><div class="pull-left">Saved listings</div><div class="badge badge-info pull-right" id="cg-menu-savedListings"></div></a></li>
#
#           <li role="presentation"><a class="clearfix" href="/Cars/sell-car/financing.action" role="menuitem"><div class="pull-left">Financing</div></a></li>
#
#
#             <li class="divider" role="presentation"></li>
#
#             <li role="presentation" style="color:#797979;">
# <a class="ft-auth-sign-in" href="/Cars/authentication/renderRegisterLoginForm.action?redirectUrl=%2FCars%2Finventorylisting%2FviewDetailsFilterViewInventoryListing.action%3FsourceContext%3DcarGurusHomePage_false_0%26formSourceTag%3D112%26newSearchFromOverviewPage%3Dtrue%26inventorySearchWidgetType%3DAUTO%26entitySelectingHelper.selectedEntity%3D%26entitySelectingHelper.selectedEntity2%3D%26zip%3D13775%26distance%3D100%26searchChanged%3Dtrue%26modelChanged%3Dtrue%26filtersModified%3Dtrue" rel="nofollow" role="menuitem" title="Sign in">Sign in</a>            </li>
#     </ul>
#   </div>
#
#   <!-- Mobile site -->
#
#   <!-- google search icon -->
#     <div class="cg-siteHeader-authBar-option">
#       <a class="cargurusSearchToggle" href="javascript:void(0);" rel="popup">
#         <div class="popover-inner hidden"><h3 class="popover-title hidden"></h3><div class="popover-content"><p></p></div></div>
#         <i class="glyphicon glyphicon-search" style="opacity:0.8"></i>
#       </a>
#   <div class="searchCarGurusForm" style="display:none;">
#     <form action="/Cars/GoogleSearchResults.html">
#       <div>
#   <input name="cx" type="hidden" value="017633193510396827519:vpr87ug-r_e"/>
#   <input name="cof" type="hidden" value="FORID:9"/>
#   <input name="ie" type="hidden" value="ISO-8859-1"/>
#         <input name="q" size="20" style="font-size:12px; padding:0; margin:0; display:inline;" type="text"/>
#         <input class="btn btn-warning btn-mini btn-xs g-searchButton" name="sa" onclick="this.form.submit();" type="submit" value="Search"/>
#       </div>
#     </form>
#   </div>
#
#       <script charset="utf-8" type="text/javascript">
#         $(function() {
#           //Init popover
#           $('.cargurusSearchToggle').popover({
#             html : true,
#             placement: 'bottom',
#             content : '<div id="popoverContent"></div>',
#             template: '<div class="popover"><div class="arrow"></div><div class="popover-inner"><h3 class="popover-title hidden"></h3><div class="popover-content"><p></p></div></div></div>'
#           }).on('click', function() {
#             var htmlToInsert = $('.searchCarGurusForm').html(),
#               popover = $(".popover"),
#               popoverContent = $('#popoverContent');
#             popoverContent.html(htmlToInsert);
#             $('#popoverContent form').attr('id', 'cse-search-box');
#
#             var script = document.createElement('script');
#             script.type = 'text/javascript';
#             script.src = 'https://cse.google.com/cse/brand?form=cse-search-box&amp;lang=en';
#             popoverContent.append(script);
#
#
#             popover.css('min-width', '220px');
#             var popoverOffsetNum = $('.cargurusSearchToggle').offset().left - (popover.width() * .90);
#             popover.css('left', popoverOffsetNum + 'px');
#             $('.popover .arrow').css('left','90%');
#             //$('#popoverContent input[name="q"]').css('background-color', '#FFFFFF');
#             //$('#popoverContent input[name="q"]').focus();
#           });
#
#         })
#       </script>
#     </div>
#
#
#   </div>
#
#
# <div class="cg-siteHeader-countryPicker">
#
#
#
#
#
#     <div class="cg-siteHeader-authBar-option">
#             <a href="https://www.cargurus.com/es/spt_carros_usados-Franklin_L24165" title="Español">Español</a>
#     </div>
#
#     <div class="dropdown cg-siteHeader-authBar-option">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="/" id="countryPicker" role="button">
#             <div class="flag-icon flag-icon-us"></div><b class="caret"></b>
#         </a>
#         <ul aria-labelledby="dLabel" class="dropdown-menu" role="menu">
# <li><a href="https://www.cargurus.com/?pid=countryPicker"><div class="flag-icon flag-icon-us"></div>
# United States</a></li>
# <li><a href="https://ca.cargurus.com/?pid=countryPicker"><div class="flag-icon flag-icon-ca"></div>
# Canada</a></li>
# <li><a href="https://www.cargurus.co.uk/?pid=countryPicker"><div class="flag-icon flag-icon-gb"></div>
# United Kingdom</a></li>
# <li><a href="https://www.cargurus.de/?pid=countryPicker"><div class="flag-icon flag-icon-de"></div>
# Deutschland</a></li>
# <li><a href="https://www.cargurus.it/?pid=countryPicker"><div class="flag-icon flag-icon-it"></div>
# Italia</a></li>
#         </ul>
#     </div>
#
# </div>
#
#   </nav>
# <div class="pull-left cg-header-tabs">
#   <ul class="pull-left">
#       <li class="nav">
# <a href="/Cars/forsale" title="Used Cars"> Used Cars </a>      </li>
#       <li class="nav">
# <a href="/Cars/new/" title="New Cars"> New Cars </a>      </li>
#       <li class="nav">
# <a href="/Cars/instantMarketValue.action" title="Car Values"> Car Values </a>      </li>
#       <li class="nav">
# <a href="/Cars/sell-car/?pid=SellMyCarMainMenuNav" onclick="CG.pageTracker.trackEvent('UserListings', 'SellYourCarLink', 'SiteTab');" title="Sell My Car"> Sell My Car <sup class="cg-private-listings__superscript">Free</sup> </a>      </li>
#       <li class="nav">
# <a href="/Cars/autos/" title="Research"> Research </a>      </li>
#       <li class="nav">
# <span class="slnk " id="" onclick="CG.Utils.slnk('L0NhcnMvcXVlc3Rpb25zLw__', false);"> Questions </span>      </li>
#   </ul>
# </div>
#     </div>
#   </nav>
#
#
#   <div id="content">
#   <div class="breadcrumbWrapper">
#       <ul class="breadcrumb clearfix" id="breadcrumb">
#
#   <li currentpage="false" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#
#       <a href="/" itemprop="url" name="breadcrumb" title="">
#         <span itemprop="title">Home</span>
#       </a>
# 	</li>
#
#
#
#   <li class="active" currentpage="true">
#     <span class="divider">/</span>
#         Used Cars
# 	</li>
#
#       </ul>
#      <!--switchCarWidget -->
#     <div class="salesHeader pull-right"></div>
#   </div>
#
# 		<div class="cg-siteHeader-leaderBoardWrap">
#       <div class="leaderboardParent">
#   <div class="cg-adslot cg-adslot--bannerAdLEADERBOARD_DealFinderBanner leaderboard leaderboard-container" data-ad-id="bannerAdLEADERBOARD_DealFinderBanner" id="bannerAdLEADERBOARD_DealFinderBanner-container">
#     <div class="leaderboard" data-ad-config='{ "id":"bannerAdLEADERBOARD_DealFinderBanner" , "format":"LEADERBOARD", "adsense_ad_format": "728x90_as" , "targeting":{} , "unitName":"/19485787/CarGurus.com/Search_Results_Page" , "sizes":[[728, 90], [234,60], [468,60]] , "adType":"PARTNER_AD" }' id="bannerAdLEADERBOARD_DealFinderBanner">
#     </div>
#   </div>
#     <script type="text/javascript">
#       (function () {
#         var slotDivId = "bannerAdLEADERBOARD_DealFinderBanner";
#         var slotConfig = {
#           id: slotDivId,
#           unitName: "\/19485787/CarGurus.com/Search_Results_Page",
#           sizes: [[728, 90], [234,60], [468,60]],
#           format: "LEADERBOARD",   // CG adFormat
#           targeting: null,
#           adType: "PARTNER_AD"  // CG adType (either TEST_AD or PARTNER_AD)
#         };
#       }());
#     </script>
#       </div>
#     </div>
#
#
#
#   <main class="" id="contentBody" role="main">
#
#   <div class="cg-listingDetailFauxPage-wrap" style="display:none;">
#       <div class="cg-listing-navWrap ft-listing-detail__results-paging showSlider" id="sliderWrapper">
#         <a class="cg-listingDetailFauxPage-backToSearchLink" href="#" onclick="USAGE_ANALYZER.logEvent('BackToSearch');"><span></span>All results
#         </a>
#         <a class="cg-listingDetailFauxPage-backLink" href="#" onclick="listingsSearchManager.hideListingDetail();" style="display:none;">
#             <i class="icon-white icon-arrow-left"></i> Back to listings
#         </a>
#     <ul id="sliderCarousel">
#         <li><img id="imgPlaceholder" src="https://static1.cargurus.com/gfx/cg/noImageAvailable_152x114.png"/></li>
#     </ul>
#       <div class="arrow-up"></div>
#     </div>
#
#       <script>
#         $(function() {
#             listingsSearchManager.initializeNav();
#         });
#       </script>
#
#       <div class="cg-listingDetailFauxPage-loading" style="display:none;">
#         <div class="alert alert-info">
#           <h2><span class="cg-iconLeft ico-loading-trans">Loading...</span></h2>
#         </div>
#       </div>
#
#       <div class="cg-listingDetailFauxPage-content" id="listingDetailFauxPage">
#       </div>
#
#   </div>
#
#   <div id="listingResultsContentBody">
#     <div class="cg-listingResults-headerWrap clearfix">
# <h1 class="clearfix ft-listing-results-header">          Used Cars for Sale in <em>Franklin, NY</em>
# </h1>
#
#
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
#
#   CG.Inventory.Filters.FilterTemplateFactory.registerDefaultTemplate(
#       new CG.Inventory.Filters.FilterTemplate(
#             "  <div>\n    <div class=\"cg-dealFinder-filter-heading clearfix\">\n      <span id=\"_#clearElementId#_\"><a href=\"javascript:void(0);\">(clear)<\/a><\/span>\n      <h3>_#filterLabelText#_<\/h3>\n    <\/div>\n\n    <div id=\"_#optionListContainerId#_\">\n        <div id=\"_#loadingPlaceholderId#_\" class=\"cg-dealFinder-filterPlaceholder invisibleLayer\">\n            Loading...\n        <\/div>\n\n        <div id=\"_#optionListId#_\" class=\"cg-dealFinder-checkboxFilter-wrap js-multi-checkbox-filter-height\" data-role=\"controlgroup\">\n        <\/div>\n\n        <span id=\"expand_#optionListId#_\" class=\"cg-options-filter-show-moreless invisibleLayer\">Show all &darr;<\/span>\n        <span id=\"collapse_#optionListId#_\" class=\"cg-options-filter-show-moreless invisibleLayer\">Show less &uarr;<\/span>\n\n    <\/div>\n  <\/div>\n",
#             "  <div class=\"cg-dealFinder-checkBoxFilter-checkBoxRow\">\n    <label for=\"_#for#_\" class=\"cg-dealFinder-checkBoxFilter-options-label\">\n       <input type=\"checkbox\" value=\"_#optionValue#_\" id=\"_#optionId#_\" data-ga-event-label=\"_#optionTextPlain#_\" data-ga-trigger-event=\"change\">\n         <span>_#optionText#_<\/span>\n           <span class=\"cg-dealFinder-checkBoxFilter-labelCount\" id=\"_#countElementId#_\">_#count#_<\/span> \n       <\/input>\n    <\/label>\n  <\/div>\n")
#   );
#
#   CG.Inventory.Filters.FilterTemplateFactory.registerTemplate(
#       'testTemplate',
#       new CG.Inventory.Filters.FilterTemplate(
#             "  <div>\n    <div class=\"cg-dealFinder-filter-heading clearfix\">\n      <span id=\"_#clearElementId#_\"><a href=\"javascript:void(0);\">(clear)<\/a><\/span>\n      <h3>_#filterLabelText#_<\/h3>\n    <\/div>\n\n    <div id=\"_#optionListContainerId#_\">\n        <div id=\"_#loadingPlaceholderId#_\" class=\"cg-dealFinder-filterPlaceholder invisibleLayer\">\n            Loading...\n        <\/div>\n\n        <div id=\"_#optionListId#_\" class=\"cg-dealFinder-checkboxFilter-wrap js-multi-checkbox-filter-height\" data-role=\"controlgroup\">\n        <\/div>\n\n        <span id=\"expand_#optionListId#_\" class=\"cg-options-filter-show-moreless invisibleLayer\">Show all &darr;<\/span>\n        <span id=\"collapse_#optionListId#_\" class=\"cg-options-filter-show-moreless invisibleLayer\">Show less &uarr;<\/span>\n\n    <\/div>\n  <\/div>\n",
#             "  <div class=\"cg-dealFinder-checkBoxFilter-checkBoxRow\">\n    <label for=\"_#for#_\" class=\"cg-dealFinder-checkBoxFilter-options-label\">\n       <input type=\"checkbox\" value=\"_#optionValue#_\" id=\"_#optionId#_\">\n         <span>_#optionText#_<\/span>\n       <\/input>\n    <\/label>\n  <\/div>\n")
#   );
#
#   CG.Inventory.Filters.FilterTemplateFactory.registerTemplate(
#       'optionWithTooltipsTemplate',
#       new CG.Inventory.Filters.FilterTemplate(
#             "  <div>\n    <div class=\"cg-dealFinder-filter-heading clearfix\">\n      <span id=\"_#clearElementId#_\"><a href=\"javascript:void(0);\">(clear)<\/a><\/span>\n      <h3>_#filterLabelText#_<\/h3>\n    <\/div>\n\n    <div id=\"_#optionListContainerId#_\">\n        <div id=\"_#loadingPlaceholderId#_\" class=\"cg-dealFinder-filterPlaceholder invisibleLayer\">\n            Loading...\n        <\/div>\n\n        <div id=\"_#optionListId#_\" class=\"cg-dealFinder-checkboxFilter-wrap js-multi-checkbox-filter-height\" data-role=\"controlgroup\">\n        <\/div>\n\n        <span id=\"expand_#optionListId#_\" class=\"cg-options-filter-show-moreless invisibleLayer\">Show all &darr;<\/span>\n        <span id=\"collapse_#optionListId#_\" class=\"cg-options-filter-show-moreless invisibleLayer\">Show less &uarr;<\/span>\n\n    <\/div>\n  <\/div>\n",
#             "  <div class=\"cg-dealFinder-checkBoxFilter-checkBoxRow\">\n    <label for=\"_#for#_\" class=\"cg-dealFinder-checkBoxFilter-options-label\">\n       <input type=\"checkbox\" value=\"_#optionValue#_\" id=\"_#optionId#_\" data-ga-event-label=\"_#optionTextPlain#_\" data-ga-trigger-event=\"change\">\n         <span>_#optionText#_<\/span>\n           <span class=\"cg-dealFinder-checkBoxFilter-labelCount\" id=\"_#countElementId#_\">_#count#_<\/span> \n       <\/input>\n    <\/label>\n  <\/div>\n",
#             "",
#             "  <div>\n    <p><strong>Year<\/strong>: _#optionYearPlaceholder#_<\/p>\n    <p><strong>MSRP<\/strong>: _#optionMsrpTextPlaceholder#_<\/p>\n    <p><strong>Description<\/strong>: _#optionDescriptionPlaceholder#_<\/p>\n  <\/div>\n",
#             "<div id=\"_#categoryContentsId#_\">\n  <div  id=\"_#categoryNameId#_\" class=\"cg-optionCategory\">\n  \t<i id=\"_#categoryChevronId#_\" class=\"icon-chevron-right\"/>\n  \t_#categoryNamePlaceholder#_\n    <div id=\"_#categoryCountsId#_\" class=\"cg-optionCategory-counts\"><span id= \"_#categorySelectedCountId#_\">0<\/span> of <span id=\"_#categoryCountId#_\">0<\/span> Selected<\/div>\n  <\/div>\n<\/div>\t\n")
#   );
#
#   CG.Inventory.Filters.FilterTemplateFactory.registerTemplate(
#       'trimWithTooltipsTemplate',
#       new CG.Inventory.Filters.FilterTemplate(
#             "  <div>\n    <div class=\"cg-dealFinder-filter-heading clearfix\">\n      <span id=\"_#clearElementId#_\"><a href=\"javascript:void(0);\">(clear)<\/a><\/span>\n      <h3>_#filterLabelText#_<\/h3>\n    <\/div>\n\n    <div id=\"_#optionListContainerId#_\">\n        <div id=\"_#loadingPlaceholderId#_\" class=\"cg-dealFinder-filterPlaceholder invisibleLayer\">\n            Loading...\n        <\/div>\n\n        <div id=\"_#optionListId#_\" class=\"cg-dealFinder-checkboxFilter-wrap js-multi-checkbox-filter-height\" data-role=\"controlgroup\">\n        <\/div>\n\n        <span id=\"expand_#optionListId#_\" class=\"cg-options-filter-show-moreless invisibleLayer\">Show all &darr;<\/span>\n        <span id=\"collapse_#optionListId#_\" class=\"cg-options-filter-show-moreless invisibleLayer\">Show less &uarr;<\/span>\n\n    <\/div>\n  <\/div>\n",
#             "  <div class=\"cg-dealFinder-checkBoxFilter-checkBoxRow\">\n    <label for=\"_#for#_\" class=\"cg-dealFinder-checkBoxFilter-options-label\">\n       <input type=\"checkbox\" value=\"_#optionValue#_\" id=\"_#optionId#_\" data-ga-event-label=\"_#optionTextPlain#_\" data-ga-trigger-event=\"change\">\n         <span>_#optionText#_<\/span>\n           <span class=\"cg-dealFinder-checkBoxFilter-labelCount\" id=\"_#countElementId#_\">_#count#_<\/span> \n       <\/input>\n    <\/label>\n  <\/div>\n",
#             "",
#             "  <div>\n            <p><strong>Base MSRP<\/strong>: _#trimMsrp#_<\/p>\n      <p><strong>MPG<\/strong>: _#trimMpg#_ <\/p>\n    <p><strong>Engine<\/strong>: _#trimEngine#_<\/p>\n    <p><strong>Transmission<\/strong>: _#trimTransmission#_<\/p>\n    <p><strong>Body Style<\/strong>: _#trimBodyStyle#_<\/p>\n    <p><strong>Fuel Type<\/strong>: _#trimFuelType#_<\/p>\n    <p><strong>Drivetrain<\/strong>: _#trimDrivetrains#_<\/p>\n    <p><strong>Seats<\/strong>: _#trimSeats#_ seats<\/p>\n  <\/div>\n",
#             "")
#   );
#
#   CG.Inventory.Filters.FilterTemplateFactory.registerTemplate(
#       'colorSwatchTemplate',
#       new CG.Inventory.Filters.FilterTemplate(
#             "  <div>\n    <div class=\"cg-dealFinder-filter-heading clearfix\">\n      <span id=\"_#clearElementId#_\"><a href=\"javascript:void(0);\">(clear)<\/a><\/span>\n      <h3>_#filterLabelText#_<\/h3>\n    <\/div>\n    <div id=\"_#optionListContainerId#_\">\n        <div id=\"_#loadingPlaceholderId#_\" class=\"cg-dealFinder-filterPlaceholder invisibleLayer\">\n          Loading...\n        <\/div>\n        <ul id=\"_#optionListId#_\" class=\"cg-colorSwatch-wrap clearfix\" data-role=\"controlgroup\">\n        <\/ul>\n    <\/div>\n  <\/div>\n",
#             "<div class=\"cg-dealFinder-checkBoxFilter-checkBoxRow colorSwatchOptionRow\" >\n    <label for=\"_#for#_\" class=\"cg-dealFinder-checkBoxFilter-label\">\n        <span class=\"colorWrap\">\n          <input type=\"checkbox\" value=\"_#optionValue#_\" id=\"_#optionId#_\">\n        <\/span>\n        <span class=\"colorName\">_#optionText#_<\/span>\n        <span class=\"cg-dealFinder-checkBoxFilter-labelCount\" id=\"_#countElementId#_\">_#count#_<\/span> \n    <\/label>\n<\/div>\n")
#   );
#
#   CG.Inventory.Filters.FilterTemplateFactory.registerTemplate(
#       'transmissionTemplate',
#       new CG.Inventory.Filters.FilterTemplate(
#             "  <div>\n    <div class=\"cg-dealFinder-filter-heading\">\n      <h3>_#filterLabelText#_<\/h3>\n    <\/div>\n    <div id=\"_#optionListContainerId#_\">\n        <div id=\"_#optionListId#_\" class=\"btn-group\" data-toggle=\"buttons\" data-role=\"controlgroup\">\n          <label class=\"btn btn-sm btn-default\" data-cg-value=\"ANY\" id=\"option_any\">\n            <input type=\"radio\" name=\"transmission-options\" autocomplete=\"off\" data-ga-event-label=\"Any\" data-ga-trigger-event=\"change\"/>Any\n          <\/label>\n          <label class=\"btn btn-sm btn-default\" data-cg-value=\"M\" id=\"option_manual\">\n            <input type=\"radio\" name=\"transmission-options\" autocomplete=\"off\" data-ga-event-label=\"Manual\" data-ga-trigger-event=\"change\"/>Manual\n          <\/label>\n          <label class=\"btn btn-sm btn-default\" data-cg-value=\"A\" id=\"option_auto\">\n            <input type=\"radio\" name=\"transmission-options\" autocomplete=\"off\" data-ga-event-label=\"Automatic\" data-ga-trigger-event=\"change\"/>Automatic\n          <\/label>\n        <\/div>\n    <\/div>\n  <\/div>\n",
#             "")
#   );
# </script>
#
#   <script type="text/javascript">
#     // If we're initially in SRP, hide the top leaderboard
#     if ($.bbq.getState("listing") == undefined || $.bbq.getState("listing") == '') {
#       $(".cg-siteHeader-leaderBoardWrap").hide();
#     }
#
#     $("#content").addClass("containsListingSearchResults");  // replacement for inline style tags
#     zipCode = '13775';
#     var baseListingDetailUrl = '\/Cars/inventorylisting/viewListingDetailAjax.action';
#
#
#
#     var listingsSearchDisplayAdMetadata = {
#         firstPageHasCpoCars: true
#     };
#     var listingsSearchManager = new ListingsSearchManager({
#         isFeaturedListingsEnabled : true,
#         isFooterFeaturedListingsEnabled : true,
#         logContext : 'carGurusHomePage_false_0',
#         pageSize : 15,
#         filterBySourcesString : '',
#         filterFeaturedBySourcesString : '',
#         newSinceDays : null,
#         isMobile : false,
#         showErrorDialog : false,
#         countryCode : 'US',
#         saveSearchUrl : '/Cars/inventorylisting/ajaxSaveListingsSearch.action',
#         saveSearchUrlMobile : '/Cars/inventorylisting/mobileSaveListingsSearch.action',
#         convertSavedSearchToSubscriptionUrl : '/Cars/inventorylisting/convertSearchToSubscriptionAjax.action',
#         subscriptionActionUrl : '/Cars/inventorylisting/subscribeAjax.action',
#         promptConvertSearchToSubscriptionUrl : '/Cars/inventorylisting/viewPromptConvertSearchToSubscriptionDialog.action',
#         viewVersion : '_DEFAULT_',
#         reportingViewVersion: '_DEFAULT_',
#         initJumpstartNewAgeType : true,
#         featuredListingsHeaderPageSize : 3,
#         featuredListingsFooterPageSize : 1,
#         isRecentSearchView : 'false',
#         inlineBannersToDisplay: 3,
#         leaderboardAdId: "bannerAdLEADERBOARD_DealFinderBanner", // not sure how to parameterize this, but it probably should be
#         isDealerPricingTool: false,
#         searchContext: 'USED',
#         ajaxFetchSubsetUrl: '/Cars/inventorylisting/ajaxFetchSubsetInventoryListing.action'
#   });
#
#   listingsSearchManager.loadsListingsOnDomLoad = true;
#
#   var contactDealer = new CG.ContactDealer(listingsSearchManager);
#   var priceAnalysisChart = new CG.PriceAnalysisChart();
#
#
#     listingsSearchManager.modelChanged = true;
#     listingsSearchManager.searchChanged = true;
#
#     if (!listingsSearchManager.isMobile) {
#         listingsSearchManager.droppedFilters = null;
#     }
#
#     var relatedCarFilter = new CG.Inventory.Filters.RelatedCarFilter('',false);
#     listingsSearchManager.registerFilter(relatedCarFilter);
#
#     var selectedTrimList = [];
#     var selectedStyleList = [];
#     var selectedTrimMap = {};
#     var selectedTrimLevelList = [];
#     var selectedTrimLevelMap = {};
#
#     var showNegotiable = true;
#     var inventorySearchWidgetType = 'AUTO';
#     var searchSeoPageType = null;
#     var minPrice = null;
#     var maxPrice = null;
#     var minMpg = null;
#     var minMileage = null;
#     var maxMileage = null;
#     var daysOnMarketMin = null;
#     var daysOnMarketMax = null;
#     var transmission = 'ANY';
#     var selectedTransmissionList = [transmission];
#     var hideAccidents = false;
#     var hideFrameDamaged = false;
#     var hideSalvage = false;
#     var hideLemon = false;
#     var hideTheft = false;
#     var hideFleet = false;
#     var hideMultipleOwners = false;
#     var hideWithoutPhotos = false;
#     var hideNotContacted = false;
#     var hideNationwideShipping = false;
#     var minCo2Emission = null;
#     var maxCo2Emission = null;
#     var vatOnly = false;
#     var minEngineDisplacement = null;
#     var maxEngineDisplacement = null;
#     var minMpg = null;
#     var maxMpg = null;
#     var hideNationwideShipping = null;
#     var minEnginePower = null;
#     var maxEnginePower = null;
#
#     var advancedSearchAutoEntities = [];
#
#
#
#
#
#
#
#       var transmissionTemplate = CG.Inventory.Filters.FilterTemplateFactory.getTemplate('transmissionTemplate');
#       var transmissionFilter = null;
#       if (listingsSearchManager.isMobile) {
#           transmissionFilter = new CG.Inventory.Filters.RadioTransmissionFilter(selectedTransmissionList, transmissionTemplate);
#       } else {
#           transmissionFilter = new CG.Inventory.Filters.TransmissionFilter(selectedTransmissionList, transmissionTemplate);
#       }
#
#       listingsSearchManager.registerFilter(transmissionFilter);
#
#     var priceDropFilter = new CG.Inventory.Filters.PriceDropFilter(false);
#     listingsSearchManager.registerFilter(priceDropFilter);
#
#
#       var accidentsFilter = new CG.Inventory.Filters.AccidentsFilter(hideAccidents);
#       listingsSearchManager.registerFilter(accidentsFilter);
#
#     listingsSearchManager.selectedModelEntityId = null;
#     listingsSearchManager.selectedEntityId = "";
#     listingsSearchManager.selectedEntity2Id = "";
#     listingsSearchManager.searchedZip = "13775";
#     listingsSearchManager.searchedRadius = "100";
#     listingsSearchManager.isBodyStyle = false;
#     listingsSearchManager.isTrimLevel = false;
#     listingsSearchManager.isSaveable = true;
#
#     listingsSearchManager.shopperListingsSearch = null;
#     listingsSearchManager.setIsNewCarSearch(false);
#
#     var selectedMakeList = null;
#     var selectedColorList = null;
#     var selectedEngineList = null;
#     var selectedFuelTypeList = null;
#     var selectedWheelSystemList = null;
#     var selectedSellerTypeList = null;
#     var selectedMpgList = null;
#     var selectedSeatingList = null;
#     var selectedRatingList = null;
#     var selectedNewUsedList = null;
#     listingsSearchManager.isCpoSearch = selectedNewUsedList != null && selectedNewUsedList.length == 1 && selectedNewUsedList.indexOf("3") != -1;
#     var selectedCabinList = null;
#     var selectedBedList = null;
#     var selectedRearWheelList = null;
#     var selectedDoorList = null;
#     var selectedBodyTypeGroupIdList = null;
#     var selectedVehicleDamageCategories = null;
#
#     var selectedInstalledOptionIdList = null;
#     var selectedInspectionRatingList = null;
#     var selectedEngineDisplacementList = null;
#
#       var makeFilter = new CG.Inventory.Filters.MakeFilter(selectedMakeList, null, listingsSearchManager.isMobile);
#       listingsSearchManager.registerFilter(makeFilter);
#
#     var truckCabinFilter = new CG.Inventory.Filters.TruckCabinFilter(selectedCabinList, null);
#     truckCabinFilter.setIsCheckedByDefault();
#     listingsSearchManager.registerFilter(truckCabinFilter);
#
#     var truckBedSizeFilter = new CG.Inventory.Filters.TruckBedSizeFilter(selectedBedList);
#     truckBedSizeFilter.setIsCheckedByDefault();
#     listingsSearchManager.registerFilter(truckBedSizeFilter);
#
#     var truckRearWheelFilter = new CG.Inventory.Filters.TruckRearWheelFilter(selectedRearWheelList);
#     truckRearWheelFilter.setIsCheckedByDefault();
#     listingsSearchManager.registerFilter(truckRearWheelFilter);
#
#     var colorFilter = new CG.Inventory.Filters.ColorFilter(selectedColorList, 'exteriorColorFilter', 'exteriorColorName', 'Color', 'colors', null);
#     colorFilter.setIsCheckedByDefault(false);
#     listingsSearchManager.registerFilter(colorFilter);
#
#     var wheelSystemFilter = new CG.Inventory.Filters.WheelSystemFilter(selectedWheelSystemList, null);
#     wheelSystemFilter.setIsCheckedByDefault();
#     listingsSearchManager.registerFilter(wheelSystemFilter);
#
#     var fuelTypeFilter = new CG.Inventory.Filters.FuelTypeFilter(selectedFuelTypeList, null);
#     fuelTypeFilter.setIsCheckedByDefault();
#     fuelTypeFilter.optionLabelMap =  {
#           0 : "Diesel",
#           1 : "Electric",
#           2 : "Gasoline",
#           3 : "Hybrid",
#           4 : "Compressed Natural Gas",
#           5 : "Flex Fuel Vehicle",
#           6 : "Biodiesel",
#           7 : "Propane",
#           8 : "Fuel Cell",
#           9 : "EcoDiesel",
#           10 : "Bi-Fuel"
#     };
#     listingsSearchManager.registerFilter(fuelTypeFilter);
#
#     var engineFilter = new CG.Inventory.Filters.EngineFilter(selectedEngineList, null);
#     engineFilter.setIsCheckedByDefault();
#     listingsSearchManager.registerFilter(engineFilter);
#
#
#         if (!listingsSearchManager.isMobile) {
#           var sliderStateMpg = new MpgSliderFilter(
#             "mpgSlider",
#             "sliderHandle1Mpg",
#             "sliderHandle2Mpg",
#             "mpgSliderLowerBoundaryLabel",
#             "mpgSliderUpperBoundaryLabel",
#             false);
#           listingsSearchManager.registerFilter(sliderStateMpg);
#         }
#
#       var seatingFilter  = new CG.Inventory.Filters.SeatingFilter(selectedSeatingList, null);
#       seatingFilter.setIsCheckedByDefault();
#       listingsSearchManager.registerFilter(seatingFilter);
#
#     var ratingFilter = new CG.Inventory.Filters.DealRatingFilter(selectedRatingList, null);
#     ratingFilter.optionLabelMap =  {
#           1 :  "Great Deal",
#           2 :  "Good Deal",
#           3 :  "Fair Deal",
#           4 :  "No Price Analysis",
#           5 :  "Fair Deal",
#           6 :  "Uncertain",
#           7 :  "High Price",
#           8 :  "Overpriced",
#     };
#
#     ratingFilter.orderedLabels = ['Great Deal',
#       'Good Deal',
#       'Fair Deal',
#       'High Price',
#       'Overpriced',
#       'No Price Analysis',
#       'Uncertain'];
#
#     ratingFilter.ratingCssClasses = {
#       1 : "cg-dealRating-great",
#       2 : "cg-dealRating-good",
#       5 : "cg-dealRating-fair",
#       7 : "cg-dealRating-poor",
#       8 : "cg-dealRating-overpriced",
#       4 : "cg-dealRating-na",
#       6 : "cg-dealRating-outlier",
#     };
#
#     ratingFilter.setIsCheckedByDefault();
#     listingsSearchManager.registerFilter(ratingFilter);
#
#     var sellerTypeFilter = new CG.Inventory.Filters.SellerTypeFilter(selectedSellerTypeList, null);
#     sellerTypeFilter.setIsCheckedByDefault();
#     listingsSearchManager.registerFilter(sellerTypeFilter);
#
#       var newUsedFilter  = new CG.Inventory.Filters.NewUsedFilter(selectedNewUsedList, null);
#       newUsedFilter.setIsCheckedByDefault();
#       listingsSearchManager.registerFilter(newUsedFilter);
#
#     if (!listingsSearchManager.isMobile) {
#       var pricelessFilter = new PricelessFilter(showNegotiable);
#       listingsSearchManager.registerFilter(pricelessFilter);
#     }
#
#     var frameDamageFilter = new CG.Inventory.Filters.FrameDamageFilter(hideFrameDamaged);
#     listingsSearchManager.registerFilter(frameDamageFilter);
#
#     var salvageFilter = new CG.Inventory.Filters.SalvageFilter(hideSalvage);
#     listingsSearchManager.registerFilter(salvageFilter);
#
#     var lemonHistoryFilter = new CG.Inventory.Filters.LemonHistoryFilter(hideLemon);
#     listingsSearchManager.registerFilter(lemonHistoryFilter);
#
#     var theftTitleFilter = new CG.Inventory.Filters.TheftTitleFilter(hideTheft);
#     listingsSearchManager.registerFilter(theftTitleFilter);
#
#     var fleetHistoryFilter = new CG.Inventory.Filters.FleetHistoryFilter(hideFleet);
#     listingsSearchManager.registerFilter(fleetHistoryFilter);
#
#     var ownerCountFilter = new CG.Inventory.Filters.OwnerCountFilter(hideMultipleOwners);
#     listingsSearchManager.registerFilter(ownerCountFilter);
#
#
#     var photosFilter = new CG.Inventory.Filters.PhotosFilter(hideWithoutPhotos);
#     listingsSearchManager.registerFilter(photosFilter);
#
#
#       var nationwideShippingFilter = new CG.Inventory.Filters.NationwideShippingFilter(hideNationwideShipping);
#       listingsSearchManager.registerFilter(nationwideShippingFilter);
#
#     var bodyTypeGroupIdToNameMap = {};
#         bodyTypeGroupIdToNameMap["6"] = 'Sedan';
#         bodyTypeGroupIdToNameMap["7"] = 'SUV / Crossover';
#         bodyTypeGroupIdToNameMap["3"] = 'Hatchback';
#         bodyTypeGroupIdToNameMap["1"] = 'Convertible';
#         bodyTypeGroupIdToNameMap["8"] = 'Van';
#         bodyTypeGroupIdToNameMap["4"] = 'Minivan';
#         bodyTypeGroupIdToNameMap["5"] = 'Pickup Truck';
#         bodyTypeGroupIdToNameMap["0"] = 'Coupe';
#         bodyTypeGroupIdToNameMap["9"] = 'Wagon';
#
#     var bodyTypeFilter = new CG.Inventory.Filters.BodyTypeFilter(selectedBodyTypeGroupIdList, bodyTypeGroupIdToNameMap, null);
#     bodyTypeFilter.setIsCheckedByDefault();
#     listingsSearchManager.registerFilter(bodyTypeFilter);
#
#       var installedOptionIdToLabelMap = {};
#         installedOptionIdToLabelMap[1] = "Leather Seats";
#         installedOptionIdToLabelMap[2] = "Sunroof/Moonroof";
#         installedOptionIdToLabelMap[4] = "Navigation System";
#         installedOptionIdToLabelMap[5] = "DVD Entertainment System";
#         installedOptionIdToLabelMap[120] = "Bluetooth";
#         installedOptionIdToLabelMap[121] = "Backup Camera";
#         installedOptionIdToLabelMap[122] = "Remote Start";
#         installedOptionIdToLabelMap[123] = "Handicap Accessible";
#         installedOptionIdToLabelMap[13] = "Tow Package";
#
#       var possiblyDroppedOptionsMap = {};
#
#       var installedOptionsFilter = new CG.Inventory.Filters.InstalledOptionsFilter(
#         selectedInstalledOptionIdList, installedOptionIdToLabelMap, possiblyDroppedOptionsMap);
#         installedOptionsFilter.setIsCheckedByDefault();
#       listingsSearchManager.registerFilter(installedOptionsFilter);
#
#
#   var sliderStatePrice = new PriceFilter(
#     "priceSlider",
#     "sliderHandle1Price",
#     "sliderHandle2Price",
#     "priceSliderLowerBoundaryLabel",
#     "priceSliderUpperBoundaryLabel",
#     false);
#
#   listingsSearchManager.registerFilter(sliderStatePrice);
#
#   var sliderStateMileage = new MileageFilter(
#     "mileageSlider",
#     "sliderHandle1mileage",
#     "sliderHandle2mileage",
#     "mileageSliderLowerBoundaryLabel",
# ...
# <span class="slnk cg-footer-socialMediaLink cg-footer-icon" id="" onclick="CG.Utils.slnk('aHR0cHM6Ly9ibG9nLmNhcmd1cnVzLmNvbQ__', true, '_blank', '');" title="CarGurus blog">
#   <svg data-name="Layer 1" id="Layer_1" style="enable-background:new 110 -310 1180 1180;" viewBox="110 -310 1180 1180" x="0px" xml:space="preserve" y="0px"><defs><style>.circle{fill:#fff;}.car{fill:#f33;}.guru{fill:#09f;}</style></defs><title>cg-2</title><circle class="circle" cx="707.7" cy="280" r="590"></circle><path class="car" d="M243.1,261.1c2.2-5.9,2-12.3,2.9-18.4,14.2-91.2,79.3-168,167.2-190.4C515.3,26.1,633,72.6,673.1,194.9c2.7,8.2,2.7,8.2-5.9,8.2-17.8,0-35.7-.1-53.5.1-3.6,0-5.2-1.2-6.6-4.4-18.6-41.5-48.4-71-92.3-84.7-64.1-19.8-130.2,2-171.7,56.4-55.3,72.5-47.5,179.4,17.8,241.7,34.2,32.6,75.2,47.7,122.3,42.5,57.1-6.3,97.3-37.5,122.6-88.4,2.4-4.8,4.7-6.8,10.3-6.6,18.3.4,36.7.2,55,.1,2.5,0,4.7-.4,3.3,3.6-19,57.6-53.3,102.7-107.8,131.1-24.6,12.9-51,20-78.6,22.6-1.1.1-2.4-.4-3.1,1h-36c-.7-1.4-2-.9-3.1-1a223.7,223.7,0,0,1-35.3-6.5C324.3,486.8,260.1,410.8,246,320.1c-1-6.3-.7-12.8-2.9-19v-40Z"></path><path class="car" d="M488,291.1c0,18.8-.1,37.7.1,56.5,0,3.4-.8,4.6-4.4,4.5-11.2-.2-22.3-.2-33.5,0-2.9,0-4-.7-4-3.8q.15-57.45,0-115c0-3,.8-4.1,3.9-4,11.3.2,22.7.2,34,0,3.6-.1,4,1.4,4,4.4C488,252.7,488,271.8,488,291.1ZM574.2,248c0,13.6-10.4,24.2-23.9,24.2A24.05,24.05,0,1,1,574.2,248ZM395.8,272.1a24.05,24.05,0,0,1-.1-48.1,24.13,24.13,0,0,1,24.2,24.1,23.84,23.84,0,0,1-24.1,24Z"></path><path class="guru" d="M972.1,42.1c7.1,2.2,14.6,2.2,21.9,3.6,45.5,8.7,84,30.1,115.8,63.5,24.2,25.4,41.1,55.1,52.5,88.1,1.5,4.5.1,5-3.8,4.9-19.2-.1-38.3-.2-57.5,0-4,0-6.1-1.2-7.9-4.9-14-29.7-34.4-53.7-62.8-70.5a146.82,146.82,0,0,0-64.2-20c-73-5.5-135.9,40.5-160.6,104-25.2,64.8-17.2,126.3,25.6,181.8,26.9,34.7,63,55.2,106.8,60,44,4.8,83.1-7.6,116.2-37.2,33.3-29.8,50.6-67.8,56-111.8a73,73,0,0,0,.9-11.4c0-3.4,1.1-4.6,4.6-4.6,17.3.2,34.7.3,52,.1,3.9,0,4.7,1.2,4.7,4.8-.2,28.4-4.8,56.1-15.2,82.5-26.3,66.7-72.8,112.4-141.7,134.1a172.7,172.7,0,0,1-41.6,7.8c-1,.1-2-.1-2.7.9h-35c-7.3-2.4-14.9-2.3-22.4-3.8a219.77,219.77,0,0,1-108-55c-40.2-37-65.4-82.8-74.1-136.5-12.7-79.1,6.8-149.6,61.4-209.2,34.9-38.1,78.5-60.9,129.6-69.2,4.5-.7,9.2-.5,13.5-2.3,12,.3,24,.3,36,.3Z"></path><path class="guru" d="M1009.6,288c24,0,48,.1,72-.1,3.6,0,5,.8,4.6,4.7-1.7,16.3-4.8,32.2-11,47.5-1.2,3-2.9,4.3-6.3,4.3q-66.3-.15-132.5,0c-3.6,0-4.4-1.2-4.4-4.6.2-15.8.2-31.7,0-47.5,0-3.7,1.3-4.4,4.6-4.3C960.9,288.1,985.2,288,1009.6,288Zm38.4-39.8a25.1,25.1,0,1,1,25.1-25A24.91,24.91,0,0,1,1048,248.2Zm-70.8-25.1a24.7,24.7,0,0,1-24.9,25.1,25.1,25.1,0,1,1,24.9-25.1Z"></path><path class="guru" d="M1208.1,50.8a40,40,0,0,1,10.3,1.4,38.15,38.15,0,0,1,9.3,3.9,39.13,39.13,0,0,1,14,14,39,39,0,0,1,0,39.2,35.66,35.66,0,0,1-6.1,7.8,38.79,38.79,0,0,1-7.9,6.1,38.15,38.15,0,0,1-9.3,3.9,38.59,38.59,0,0,1-20.6,0,38.26,38.26,0,0,1-17-10,42,42,0,0,1-6.1-7.8,39.15,39.15,0,0,1-3.9-9.2,39,39,0,0,1,3.9-29.9,38.79,38.79,0,0,1,6.1-7.9,42,42,0,0,1,7.8-6.1,39.15,39.15,0,0,1,9.2-3.9A35.65,35.65,0,0,1,1208.1,50.8Zm0,72.9a33.82,33.82,0,0,0,17.1-4.6,32.68,32.68,0,0,0,12-12.2,30.92,30.92,0,0,0,3.4-8.2,35,35,0,0,0,1.2-9.1,36.31,36.31,0,0,0-2.6-13.4,33.41,33.41,0,0,0-7.2-10.9,33.93,33.93,0,0,0-10.7-7.3,33.52,33.52,0,0,0-13.2-2.7,34.24,34.24,0,0,0-9,1.2,33.21,33.21,0,0,0-8,3.4,31.3,31.3,0,0,0-6.7,5.3,34.7,34.7,0,0,0-5.2,6.9,39.08,39.08,0,0,0-3.3,8.2,35.11,35.11,0,0,0,0,18.2,41.37,41.37,0,0,0,3.3,8.2,34.7,34.7,0,0,0,5.2,6.9,38.12,38.12,0,0,0,6.7,5.3,33.21,33.21,0,0,0,8,3.4A34.46,34.46,0,0,0,1208.1,123.7Zm-.6-57.8c6.1,0,10.6,1.1,13.6,3.3s4.4,5.5,4.4,9.8a13,13,0,0,1-2.8,8.5,14.94,14.94,0,0,1-8.4,4.8,10.7,10.7,0,0,1,1.6,1.4,7.6,7.6,0,0,1,1.2,1.9l12.1,17.7h-7.9a2.58,2.58,0,0,1-2.5-1.3l-10.7-16a5.73,5.73,0,0,0-1.1-1.1,4.48,4.48,0,0,0-2-.4h-4.2v18.8h-8.3V65.9Zm-.9,22.5c3.9,0,6.7-.7,8.3-2.2a7.66,7.66,0,0,0,2.4-6.2,13.45,13.45,0,0,0-.5-3.5,4.87,4.87,0,0,0-1.6-2.4,8.26,8.26,0,0,0-3-1.4,24,24,0,0,0-4.6-.5h-7V88.3h6Z"></path></svg>
#
# </span>            </div>
#       <p>© 2018 CarGurus ®, Inc., All Rights Reserved.</p>
#     </div>
#
#   </footer>
#
#   <script>
#     // Feature detection
#     (function (d, tests) {
#       var i, classArr,
#           features = tests;
#
#       if (typeof CG === 'object' && CG !== null && CG.hasOwnProperty('Utils')) {
#         for (var prop in features) {
#           if (CG.Utils.isSupportedCSS(prop)) {
#             CG.Utils.classList.remove('no-' + features[prop]);
#             CG.Utils.classList.add(features[prop]);
#           }
#           else {
#             CG.Utils.classList.add('no-' + features[prop]);
#           }
#         }
#       }
#     })(document, { 'box-flex': 'flexbox', 'flex': 'flexbox' });
#   </script>
#
#   <script>
#     if (typeof CG === 'object' && CG !== null && CG.hasOwnProperty('Utils')) {
#       if (CG.Utils.isTouch()) {
#         CG.Utils.classList.add('touch');
#       }
#       else {
#         CG.Utils.classList.add('no-touch');
#       }
#     }
#   </script>
#
#
#         <script type="text/javascript">
#             var isModal = false;
#             $(window).on("load", function() {
#                 if (typeof CG === 'object' && CG !== null && CG.hasOwnProperty('UserFeedbackWidget')) {
#                   CG.UserFeedbackWidget.init({
#                     showAsModal: isModal,
#                     locale: "en_US",
#                     src: '!function(e,o,n){window.HSCW=o,window.HS=n,n.beacon=n.beacon||{};var t=n.beacon;t.userConfig={},t.readyQueue=[],t.config=function(e){this.userConfig=e},t.ready=function(e){this.readyQueue.push(e)},o.config={docs:{enabled:!0,baseUrl:"//cargurus.helpscoutdocs.com/"},contact:{enabled:!0,formId:"f8d1ebfd-96f6-11e6-91aa-0a5fecc78a4d"}};var r=e.getElementsByTagName("script")[0],c=e.createElement("script");c.type="text/javascript",c.async=!0,c.src="https://djtflbt20bdde.cloudfront.net/",r.parentNode.insertBefore(c,r)}(document,window.HSCW||{},window.HS||{});'
#                   });
#                 }
#               });
#         </script>
#
# <script type="text/javascript">
#   if (typeof CG === 'object' && CG !== null && CG.hasOwnProperty('GoogleData')) {
#     CG.GoogleData.assembleAndPush('data_tag');
#   }
# </script>
#
#
#
#     <script type="text/javascript">
#       if (typeof CG === 'object' && CG !== null && CG.hasOwnProperty('pageTracker')) {
#         CG.pageTracker.trackCurrentGAPageview("ForSale-x-false");
#       }
#     </script>
#   <script type="text/javascript">
#     //Hide jquery migrate traces
#     jQuery.migrateTrace =  false;
#     jQuery.migrateMute =  true;
#     $(window).on("load", function() {
#           $(window).trigger("LogTime", ["/Cars/inventorylisting/viewDetailsFilterViewInventoryListing.action", 'load']);
#     });
#   </script>
#
#
#
#       <div class="modal fade cg-surveyModal" data-controller="Survey.Modal" role="dialog" tabindex="-1">
#         <div class="modal-dialog" role="document">
#           <div class="modal-content">
#             <div class="modal-header">
#               <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#                 <span aria-hidden="true">×</span>
#               </button>
#               <div class="modal-title">
#   <svg id="Layer_1" version="1.1" viewBox="549 97 2058 367" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#     <g>
#       <path class="guru" d="M1604.6,227.8c-5.5,0-11-0.2-16.5,0.1c-3.5,0.2-5.2-1-6.8-4.2c-15.1-29.9-38.2-49.9-71.8-55.3
#         c-36.4-5.8-67,6.2-91.6,33.2c-45,49.3-35.3,130.8,19.8,168.3c52.8,35.9,122.5,14,146.9-46.3c4.8-11.8,7.9-24.1,8.4-36.8
#         c0.2-4,1.5-5.3,5.6-5.2c10,0.3,20,0.2,30,0c3,0,4,0.9,4,4c-0.7,70.7-49.6,130-116.1,140.7c-65.1,10.5-127.3-24.2-154.6-85.5
#         c-26.1-58.7-13.4-129,31.5-173.4c72.2-71.4,188.5-48.2,228.4,45.4c1.6,3.7,2.6,7.5,4.3,11.2c1.6,3.5,0.1,3.9-2.9,3.9
#         C1617,227.7,1610.8,227.8,1604.6,227.8L1604.6,227.8z M2327.5,347h17.5c1.9,0,3.2,0.4,3.6,2.5c4.4,21.1,19.3,31,38.8,35.2
#         c15.1,3.3,30.1,2.4,44.6-3.4c5.8-2.3,10.8-5.8,14.9-10.6c10.5-12.3,7.2-27.9-7.4-34.6c-13-6-27.1-7.7-41.1-9.8
#         c-15.6-2.3-31.2-5.1-46.1-10.7c-19.6-7.4-34.3-19.3-37.3-41.4c-3.1-23.1,4.6-42.3,22.8-57c13-10.4,28.2-15.5,44.5-17.4
#         c23.6-2.8,46.6-1,68,10.5c22.9,12.3,35,31.9,37.9,57.5c0.3,2.2-0.3,3.1-2.5,3.1h-36c-1.8,0-2.6-0.9-3-2.6
#         c-4.5-19.2-18.2-27.9-36.4-30.5c-12.8-1.9-25.6-0.8-37.7,4.5c-4.8,2.1-9.1,4.9-12.5,8.9c-8.2,9.6-5.8,21.1,5.8,26
#         c12.2,5.2,25.3,7,38.2,9.1c16.1,2.7,32,5.8,47.6,10.7c54.7,17.2,48.2,82.7,18.8,106.6c-16.3,13.3-35,19.5-55.5,21.1
#         c-24.6,1.9-48.2-1.5-69.7-14.5c-22.3-13.6-34.7-33.8-38.4-59.6c-0.4-2.6,0.2-3.6,3-3.5C2315.8,347.2,2321.6,347,2327.5,347
#         L2327.5,347z M1797.6,405.1c-11.4,10.3-23.2,17.2-36.9,20.5c-33.2,8-74-1.8-93.4-39.2c-7.8-15.1-11-31.4-11-48.2
#         c-0.2-42,0-84-0.1-125.9c0-3.8,0.8-5.2,4.9-5.1c10.3,0.3,20.7,0.3,31,0c4.2-0.1,4.8,1.4,4.8,5.1c-0.1,40.6-0.1,81.3-0.1,121.9
#         c0,9.4,0.7,18.6,4,27.5c7,18.6,23.5,29,45.3,28.6c29-0.6,50.1-22.2,50.1-51.2c0-42,0.1-84-0.1-125.9c0-4.9,1.4-6.1,6.1-6
#         c10,0.4,20,0.3,30,0c4.4-0.1,5.5,1,5.5,5.5c-0.2,64.5-0.1,128.9-0.1,193.4c0,4.5-0.2,9,0.1,13.5c0.1,2.9-0.9,3.7-3.7,3.6
#         c-11-0.1-22-0.1-33,0c-2.6,0-3.5-0.7-3.4-3.4C1797.8,415.5,1797.6,411,1797.6,405.1L1797.6,405.1z M2238,405
#         c-12.5,11.6-26,18.9-41.7,21.6c-41.2,7.2-86.9-10.9-97.5-66.4c-1.6-8.2-2.1-16.5-2.1-24.8c0-41,0.1-82-0.1-123
#         c0-4.2,1.1-5.3,5.3-5.2c10.2,0.3,20.3,0.3,30.5,0c3.9-0.1,5,1.1,5,5c-0.1,42.2-0.1,84.3-0.1,126.5c0,12.9,2.5,25.3,11,35.5
#         c12.1,14.6,28.4,18.2,46.1,15.2c26.2-4.4,42.4-24.5,42.5-51.3c0.1-41.8,0.1-83.6-0.1-125.5c0-4.3,0.9-5.7,5.4-5.5
#         c10.5,0.4,21,0.2,31.5,0.1c3.1,0,4.3,0.6,4.3,4.1c-0.1,69.3-0.1,138.6,0,207.9c0,2.9-0.6,4-3.8,4c-10.8-0.2-21.7-0.2-32.5,0
#         c-2.8,0-3.8-0.8-3.7-3.7C2238.1,415.1,2238,410.7,2238,405L2238,405z" fill="#0099FF"></path>
#       <path class="guru" d="M1930,225.4c8.2-7.4,16.2-13.2,25.5-17c41.1-16.6,103.4-3.1,114.3,65.2c1.8,11.4,1.3,22.9,1.5,34.4
#         c0,2.7-0.9,3.4-3.5,3.4c-11.2-0.1-22.3-0.1-33.5,0c-2.9,0-3.6-1-3.6-3.7c0.1-9.6,0.7-19.3-1.3-28.9c-4.8-23.3-20.7-37.4-43.3-38.4
#         c-24.7-1.1-45.2,12.3-52.2,34.3c-1.8,5.7-2.6,11.7-2.6,17.7c0,41.8-0.1,83.6,0.1,125.4c0,4.3-0.9,5.7-5.4,5.5
#         c-10.3-0.4-20.7-0.2-31-0.1c-3.3,0.1-4.6-0.5-4.6-4.2c0.1-69.1,0.1-138.3,0-207.4c0-3.1,0.7-4.4,4.1-4.3c10.5,0.2,21,0.2,31.5,0
#         c3.5-0.1,4.3,1.2,4.1,4.3C1929.8,215.8,1930,219.9,1930,225.4L1930,225.4z M1528.8,281.6c15,0,30,0.1,45,0c2.8,0,4.4,0.3,3.9,3.8
#         c-1.3,9.8-3.1,19.4-6.6,28.6c-1.2,3.2-3,4.2-6.3,4.2c-27.2-0.1-54.3-0.1-81.5,0c-3.3,0-4.7-0.5-4.6-4.3c0.3-9.3,0.3-18.7,0-28
#         c-0.1-3.7,1.3-4.3,4.6-4.3C1498.5,281.7,1513.6,281.6,1528.8,281.6L1528.8,281.6z M1508,240.9c-0.1,9-7.4,16.3-16.3,16.1
#         c-8.9-0.2-16.1-7.8-15.9-16.6c0.2-8.7,7.4-15.8,16.1-15.7C1501,224.7,1508,231.8,1508,240.9L1508,240.9z M1569.3,240.9
#         c-0.1,8.9-7.7,16.2-16.4,16.1c-8.7-0.1-16.1-7.9-15.9-16.6c0.2-8.6,7.5-15.7,16.2-15.8C1562,224.6,1569.4,232,1569.3,240.9
#         L1569.3,240.9z" fill="#0099FF"></path>
#     </g>
#     <g>
#       <path class="car" d="M835.4,228.2c-6.5,0-13.6,1.7-19.3-0.5c-5.9-2.2-6.5-10.5-9.9-15.8c-29.8-46.9-92.3-59.1-138.3-26.8
#         c-62.4,43.7-61.9,143,1,186c49.2,33.7,115.2,16.6,142.2-36.9c2.6-5.2,5.2-7.3,11.1-6.9c10.5,0.6,21,0.2,31.5,0.1
#         c2.6,0,3.6,0.3,2.6,3.3c-17.1,53-60.6,90.6-116.8,96.7c-68.3,7.4-129.4-35.5-149.8-98.1c-20.4-62.8-7.5-119,40.8-164.9
#         c53.8-51.3,141.4-48.6,193.3,4.7c15.2,15.7,25.5,34.3,32.2,55.1c1.2,3.6,0.2,4.2-3.1,4.1C847.1,228,841.3,228.2,835.4,228.2z
#          M1051.2,235c0-8.6,0.2-15.9-0.1-23.2c-0.1-3.5,1-4.5,4.5-4.5c10.3,0.2,20.7,0.2,31,0c3,0,4.4,0.5,4.4,4c-0.1,69.3-0.1,138.7,0,208
#         c0,3-0.7,4-3.8,4c-10.7-0.2-21.3-0.2-32,0c-3.6,0.1-4.1-1.4-4-4.4c0.1-7.4,0-14.8,0-23.4c-6.4,6.5-11.7,12.2-18.2,16.5
#         c-35.1,23.4-70.9,21.6-105.9,1c-32.6-19.3-49.4-49.7-52.4-87.2c-3.1-37.9,8.5-70.7,36.8-96.7c29.9-27.4,73.4-34.6,107.8-18.6
#         c5.9,2.8,11.4,6.2,16.6,10.2C1041.1,224.6,1045.7,229.2,1051.2,235L1051.2,235z M915.3,315.7c-0.2,12.9,2.8,25.1,8.7,36.5
#         c21.7,41.7,74.1,49.5,105.4,15.8c28.2-30.5,27.2-77.5-2.2-106.9c-25.2-25.1-61.8-26.1-87.9-2C922.9,274.2,915.7,293.5,915.3,315.7z
#          M1183.6,225.5c13.8-13,29-20.6,46.8-22.7c42.2-4.9,82.2,16,92.3,67c2.5,12.7,2.2,25.5,2.2,38.3c0,2.3-0.6,3.2-3.1,3.2
#         c-11.5-0.1-23-0.1-34.5,0c-3.4,0-3.2-1.9-3.2-4.1c-0.1-9.1,0.7-18.3-1-27.4c-5-25.9-22.1-39.8-48.4-39.5
#         c-24.7,0.3-45.1,17.6-49,41.6c-0.7,4-1,7.9-1,11.9c0,41.5,0,83,0.1,124.5c0,3.8-0.8,5.1-4.8,5c-10.8-0.3-21.7-0.2-32.5,0
#         c-3.2,0.1-3.8-0.9-3.8-3.9c0.1-69.3,0.1-138.6,0-208c0-2.8,0.4-4.2,3.7-4.1c10.8,0.2,21.7,0.2,32.5,0c2.8,0,3.9,0.7,3.7,3.6
#         C1183.5,215.4,1183.6,219.9,1183.6,225.5L1183.6,225.5z" fill="#FF3333"></path>
#       <path class="car" d="M710.6,283.2c0-11.5,0.1-23-0.1-34.5c-0.1-3.3,0.9-4.3,4.2-4.2c6.3,0.3,12.6,0.2,19,0
#         c2.8-0.1,3.8,0.8,3.7,3.7c-0.1,23.6-0.1,47.3,0,70.9c0,2.9-0.9,3.7-3.7,3.7c-6.3-0.2-12.7-0.2-19,0c-3.3,0.1-4.2-0.9-4.2-4.2
#         C710.7,306.8,710.6,295,710.6,283.2z M761.6,256.7c0-8.8,6.7-15.6,15.4-15.5c8.6,0.1,15.4,7,15.3,15.7c-0.1,8.4-6.9,15.2-15.2,15.3
#         C768.5,272.3,761.6,265.4,761.6,256.7z M693.8,256.7c0,8.6-7,15.5-15.6,15.5c-8.5-0.1-15.4-7.2-15.3-15.8
#         c0.1-8.4,6.9-15.1,15.3-15.2C686.9,241.1,693.8,248.1,693.8,256.7z" fill="#FF3333"></path>
#     </g>
#     <g>
#       <path class="guru" d="M2580.5,206.7c-1.6,1.4-1.5,3.6-2.2,5.3c-6.8,17.8-24.3,27.7-43.2,24.4c-17.8-3.1-31.1-19-31.4-37.4
#         c-0.3-18.1,12.6-34,30.8-37.9c18.5-4,37.2,6.6,43.9,24.7c0.6,1.6,0.3,3.7,2,4.9C2580.5,196,2580.5,201.4,2580.5,206.7L2580.5,206.7
#         z M2542.5,166.4c-18-0.1-31.4,13.6-31.6,32.1c-0.2,18.1,13.7,32.8,31.1,33c17.4,0.2,31.4-14.2,31.5-32.5
#         C2573.6,180.4,2560.4,166.5,2542.5,166.4L2542.5,166.4z" fill="#0099FF"></path>
#       <path class="guru" d="M2560.1,220.5c-4.3,1.5-7.2,0.3-9.3-3.9c-2.1-4.1-5.1-7.8-7.3-11.9c-1.7-3.3-4.4-3.3-7.2-2.8
#         c-3.4,0.6-1.6,3.5-1.8,5.3c-0.3,3.5-0.2,7,0,10.5c0.1,2.7-1.1,3.3-3.6,3.3s-3.6-0.7-3.5-3.4c0.1-12.6,0.1-25.3,0-37.9
#         c0-2.2,0.6-3.4,3.1-3.3c6,0.2,12-0.1,17.9,0.2c7.1,0.4,10.9,4,11.8,10.5c0.9,6.6-1.7,11.1-8.4,13.3c-3.4,1.1-2.3,2.3-1.1,4.2
#         l9.3,14.7C2560.3,219.7,2560.1,220.1,2560.1,220.5L2560.1,220.5z M2534.5,189c0,8,0,8,7.8,7.2c1.8-0.2,3.6-0.2,5.4-0.5
#         c3.6-0.6,5.5-2.9,5.6-6.5c0.1-3.3-1.5-5.8-4.9-6.5c-2.2-0.5-4.6-0.8-6.9-0.8C2533.2,181.9,2534.6,181,2534.5,189L2534.5,189z" fill="#0099FF"></path>
#     </g>
#   </svg>
#               </div>
#             </div>
#
#             <div class="modal-body">
#               <div class="well">
#                 <p>Got a minute?</p>
#                 <p>Take our two-question survey!</p>
#               </div>
#
#               <p>Your answers will help make CarGurus better for shoppers everywhere.</p>
#               <div class="container-fluid">
#                 <div class="row cg-surveyModal-buttons">
#                   <div class="col-xs-6 text-center">
#                     <button class="btn btn-default" onclick="CG.Survey.Modal.hide();" type="button">
#                       No Thanks
#                     </button>
#                   </div>
#                   <div class="col-xs-6 text-center">
#                     <button class="btn btn-primary" onclick="CG.Survey.Modal.launchSurvey();" type="button">
#                       Take the Survey
#                     </button>
#                   </div>
#                 </div>
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#
#
#   <div class="hidden" data-action-class="com.cargurus.site.action.inventorylisting.InventoryListingAction" data-action-method="viewDetailsFilterView" data-build-id="cg-main-16350" data-production="true" data-sentry="https://0e1a93256b16472d9067a95b7c2017f7@sentry.io/100939" data-sentry-integrated="true" data-server-host-name="www05.cargurus.com" data-template="/inventorylisting/viewDetailsFilterView.ftl" data-view-version="_DEFAULT_" id="devInfo" style="display: none;">
#   </div>
#
#
# </body></html>

# %%
chromedriver = "/usr/local/bin/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-6-109f01265c48> in <module>()
#       1 chromedriver = "/usr/local/bin/chromedriver"
#       2 os.environ["webdriver.chrome.driver"] = chromedriver
# ----> 3 driver = webdriver.Chrome(chromedriver)
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options)
#      73                 command_executor=ChromeRemoteConnection(
#      74                     remote_server_addr=self.service.service_url),
# ---> 75                 desired_capabilities=desired_capabilities)
#      76         except Exception:
#      77             self.quit()
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     152             warnings.warn("Please use FirefoxOptions to set browser profile",
#     153                           DeprecationWarning)
# --> 154         self.start_session(desired_capabilities, browser_profile)
#     155         self._switch_to = SwitchTo(self)
#     156         self._mobile = Mobile(self)
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     241         parameters = {"capabilities": w3c_caps,
#     242                       "desiredCapabilities": capabilities}
# --> 243         response = self.execute(Command.NEW_SESSION, parameters)
#     244         if 'sessionId' not in response:
#     245             response = response['value']
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: Chrome failed to start: exited abnormally
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.4.0-121-generic x86_64)

# %%
chromedriver = "/usr/local/bin/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)
driver.get(link)
print("\n 3...")
time.sleep(1)
print("\n 2...")
time.sleep(1)
print("\n 1...")
time.sleep(1)
assert "CarGurus" in driver.title
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-fe72a1515c7c> in <module>()
#       1 chromedriver = "/usr/local/bin/chromedriver"
#       2 os.environ["webdriver.chrome.driver"] = chromedriver
# ----> 3 driver = webdriver.Chrome(chromedriver)
#       4 driver.get(link)
#       5 print("\n 3...")
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options)
#      73                 command_executor=ChromeRemoteConnection(
#      74                     remote_server_addr=self.service.service_url),
# ---> 75                 desired_capabilities=desired_capabilities)
#      76         except Exception:
#      77             self.quit()
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     152             warnings.warn("Please use FirefoxOptions to set browser profile",
#     153                           DeprecationWarning)
# --> 154         self.start_session(desired_capabilities, browser_profile)
#     155         self._switch_to = SwitchTo(self)
#     156         self._mobile = Mobile(self)
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     241         parameters = {"capabilities": w3c_caps,
#     242                       "desiredCapabilities": capabilities}
# --> 243         response = self.execute(Command.NEW_SESSION, parameters)
#     244         if 'sessionId' not in response:
#     245             response = response['value']
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: Chrome failed to start: exited abnormally
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Linux 4.4.0-121-generic x86_64)
